# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
help("lambda")
# Out:
# Lambdas
# *******
#
#    lambda_expr        ::= "lambda" [parameter_list] ":" expression
#    lambda_expr_nocond ::= "lambda" [parameter_list] ":" expression_nocond
#
# Lambda expressions (sometimes called lambda forms) are used to create
# anonymous functions. The expression "lambda parameters: expression"
# yields a function object.  The unnamed object behaves like a function
# object defined with:
#
#    def <lambda>(parameters):
#        return expression
#
# See section Function definitions for the syntax of parameter lists.
# Note that functions created with lambda expressions cannot contain
# statements or annotations.
#
# Related help topics: FUNCTIONS

# %%
func = lambda x: x

# %%
[(k, type(v)) for k, v in sorted(tfds.__dict__.items(), key=lambda x: str(x[1]))]
# Out:
# [('__version__', str),
#  ('__loader__', _frozen_importlib_external.SourceFileLoader),
#  ('ImageFolder', abc.ABCMeta),
#  ('TranslateFolder', abc.ABCMeta),
#  ('Split', type),
#  ('ReadConfig', type),
#  ('GenerateMode', enum.EnumMeta),
#  ('as_dataframe', function),
#  ('as_numpy', function),
#  ('builder', function),
#  ('builder_cls', function),
#  ('disable_progress_bar', function),
#  ('even_splits', function),
#  ('is_dataset_on_gcs', function),
#  ('list_builders', function),
#  ('load', function),
#  ('show_examples', function),
#  ('show_statistics', function),
#  ('sys', module),
#  ('__init__py3', module),
#  ('api', module),
#  ('audio', module),
#  ('core', module),
#  ('decode', module),
#  ('deprecated', module),
#  ('download', module),
#  ('features', module),
#  ('folder_dataset', module),
#  ('typing', module),
#  ('visualization', module),
#  ('image', module),
#  ('image_classification', module),
#  ('object_detection', module),
#  ('proto', module),
# ...

# %% [markdown]
# # tensorflow_datasets
#
# **DESCRIPTION**
#
# 每个数据集被定义为`tfds.core.DatasetBuilder`，它封装了下载数据集和构造输入 pipeline 的 logic，以及数据集文档；加载数据集主要函数有：
# - `tfds.builder`: 根据名称获取一个`tfds.core.DatasetBuilder`
# - `tfds.load`: 创建一个构建函数、下载数据、创建输入 pipeline，并返回一个`tf.data.Dataset`
#
# 相关帮助文档有：
# - [Available datasets](https://www.tensorflow.org/datasets/catalog/overview)
# - [Colab tutorial](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb)
# - [Add a dataset](https://www.tensorflow.org/datasets/add_dataset)
#
# **PACKAGES**
#
#     __init__py2
#     __init__py3
#     audio (package)
#     conftest
#     core (package)
#     image (package)
#     image_classification (package)
#     import_public_api_test
#     import_test
#     object_detection (package)
#     proto (package)
#     public_api
#     question_answering (package)
#     scripts (package)
#     structured (package)
#     summarization (package)
#     testing (package)
#     text (package)
#     translate (package)
#     version
#     video (package)
#
# **SUBMODULES**
#
#     api
#     decode
#     deprecated
#     download
#     features
#     folder_dataset
#     typing
#     visualization
#
# **CLASSES**
#
#     GenerateMode(enum.Enum)
#     ImageFolder(tensorflow_datasets.core.dataset_builder.DatasetBuilder)
#     ReadConfig(builtins.object)
#     Split(builtins.str)
#     TranslateFolder(tensorflow_datasets.core.dataset_builder.DatasetBuilder)
#
# **FUNCTIONS**
#
#     as_dataframe
#     as_numpy
#     builder
#     builder_cls
#     disable_progress_bar
#     even_splits
#     is_dataset_on_gcs
#     list_builders
#     load
#     show_examples
#     show_statistics
#
# **FILE**： \tensorflow_datasets\\\_\_init__.py

# %%
help(tfds.image_classification)
# Out:
# Help on package tensorflow_datasets.image_classification in tensorflow_datasets:
#
# NAME
#     tensorflow_datasets.image_classification - Image Classification datasets.
#
# PACKAGE CONTENTS
#     beans
#     beans_test
#     bigearthnet
#     bigearthnet_test
#     binary_alpha_digits
#     binary_alpha_digits_test
#     caltech
#     caltech_birds
#     caltech_birds_test
#     caltech_test
#     cars196
#     cars196_test
#     cassava
#     cassava_test
#     cats_vs_dogs
#     cats_vs_dogs_test
#     cbis_ddsm
#     cbis_ddsm_test
#     chexpert
#     chexpert_test
#     cifar
#     cifar10_1
#     cifar10_1_test
#     cifar10_corrupted
#     cifar10_corrupted_test
#     cifar_test
#     citrus
#     citrus_test
#     cmaterdb
#     cmaterdb_test
#     colorectal_histology
#     colorectal_histology_test
#     corruptions
#     cycle_gan
#     cycle_gan_test
#     deep_weeds
#     deep_weeds_test
#     diabetic_retinopathy_detection
#     diabetic_retinopathy_detection_test
# ...
