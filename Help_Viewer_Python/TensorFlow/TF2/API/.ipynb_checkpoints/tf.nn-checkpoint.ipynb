# %%
import tensorflow as tf
import tensorflow.nn as nn

# %% [markdown]
# <div align=center>
#
# # Activation Functions
# </div>

# %% [markdown]
# # tf.nn.sigmoid()
# `tf.nn.sigmoid(x, name=None)`
#
# **Docstring**:
#
# `x`应为任意形状的`float16`、`float32`、`float64`、`complex64`、`complex128`的`Tensor`；返回值与`x`类型相同；该函数等价于`scipy.special.expit`
#
#
# **File**:    \tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py
#
# **Type**:      function

# %%
x = tf.constant([[1., 2.], [3., 4.]])
print(tf.nn.sigmoid(x))

# %% [markdown]
# #

# %% [markdown]
# # tf.nn.relu()
# `tf.nn.relu(features, name=None)`
#
# **Docstring**:
#
# `features`应为任意形状的`float32`, `float64`, `int32`, `uint8`, `int16`, `int8`, `int64`, `bfloat16`, `uint16`, `half`, `uint32`, `uint64`, `qint8`的`Tensor`；返回值与`feature`类型相同；
#
# **File**:   \tensorflow\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py
#
# **Type**:      function

# %%
x = tf.constant([[-1, 0, 1], [-3, -5, 7]])
print(tf.nn.relu(x))

# %% [markdown]
# #

# %%
for k, v in tf.nn.__dict__.items():
    if callable(v):
        print(k, v, sep="\n")
        print()
# Out:
# RNNCellDeviceWrapper
# <class 'tensorflow.python.keras.layers.rnn_cell_wrapper_v2.DeviceWrapper'>
#
# RNNCellDropoutWrapper
# <class 'tensorflow.python.keras.layers.rnn_cell_wrapper_v2.DropoutWrapper'>
#
# RNNCellResidualWrapper
# <class 'tensorflow.python.keras.layers.rnn_cell_wrapper_v2.ResidualWrapper'>
#
# depth_to_space
# <function depth_to_space_v2 at 0x0000020C59BC7D30>
#
# space_to_batch
# <function space_to_batch_v2 at 0x0000020C59BC7AF0>
#
# space_to_depth
# <function space_to_depth_v2 at 0x0000020C59BC7C10>
#
# all_candidate_sampler
# <function all_candidate_sampler at 0x0000020C5B8AEF70>
#
# compute_accidental_hits
# <function compute_accidental_hits at 0x0000020C5B8B2040>
#
# fixed_unigram_candidate_sampler
# <function fixed_unigram_candidate_sampler at 0x0000020C5B894550>
#
# learned_unigram_candidate_sampler
# <function learned_unigram_candidate_sampler at 0x0000020C5B8AEEE0>
#
# collapse_repeated
# <function collapse_repeated at 0x0000020C5B887040>
#
# ctc_beam_search_decoder
# <function ctc_beam_search_decoder_v2 at 0x0000020C5B885820>
#
# ctc_greedy_decoder
# <function ctc_greedy_decoder at 0x0000020C5B885700>
#
# ctc_loss
# <function ctc_loss_v3 at 0x0000020C5B885EE0>
#
# ctc_unique_labels
# <function ctc_unique_labels at 0x0000020C5B887160>
#
# embedding_lookup_sparse
# <function embedding_lookup_sparse_v2 at 0x0000020C5B887A60>
#
# embedding_lookup
# <function embedding_lookup_v2 at 0x0000020C5B887940>
#
# safe_embedding_lookup_sparse
# <function safe_embedding_lookup_sparse_v2 at 0x0000020C5B887AF0>
#
# tanh
# <function tanh at 0x0000020C59BB2D30>
#
# depthwise_conv2d_backprop_filter
# <function depthwise_conv2d_native_backprop_filter at 0x0000020C48ADA940>
#
# depthwise_conv2d_backprop_input
# <function depthwise_conv2d_native_backprop_input at 0x0000020C48ADAB80>
#
# elu
# <function elu at 0x0000020C48ADE430>
#
# l2_loss
# <function l2_loss at 0x0000020C48AEDB80>
#
# lrn
# <function lrn at 0x0000020C48AEDDC0>
#
# local_response_normalization
# <function lrn at 0x0000020C48AEDDC0>
#
# relu
# <function relu at 0x0000020C48B22C10>
#
# selu
# <function selu at 0x0000020C48B26550>
#
# softplus
# <function softplus at 0x0000020C48B28280>
#
# softsign
# <function softsign at 0x0000020C48B28700>
#
# sigmoid
# <function sigmoid at 0x0000020C48B475E0>
#
# batch_norm_with_global_normalization
# <function batch_norm_with_global_normalization_v2 at 0x0000020C5B8B89D0>
#
# batch_normalization
# <function batch_normalization at 0x0000020C5B8B8820>
#
# compute_average_loss
# <function compute_average_loss at 0x0000020C5B8B2A60>
#
# depthwise_conv2d
# <function depthwise_conv2d_v2 at 0x0000020C5B8B8280>
#
# l2_normalize
# <function l2_normalize_v2 at 0x0000020C5B8B2F70>
#
# log_poisson_loss
# <function log_poisson_loss at 0x0000020C5B887DC0>
#
# moments
# <function moments_v2 at 0x0000020C5B8B8670>
#
# nce_loss
# <function nce_loss_v2 at 0x0000020C5B8B8B80>
#
# normalize_moments
# <function normalize_moments at 0x0000020C5B8B8550>
#
# sampled_softmax_loss
# <function sampled_softmax_loss_v2 at 0x0000020C5B8B8CA0>
#
# scale_regularization_loss
# <function scale_regularization_loss at 0x0000020C5B8B29D0>
#
# separable_conv2d
# <function separable_conv2d_v2 at 0x0000020C5B8B83A0>
#
# sigmoid_cross_entropy_with_logits
# <function sigmoid_cross_entropy_with_logits_v2 at 0x0000020C5B8B2820>
#
# sufficient_statistics
# <function sufficient_statistics_v2 at 0x0000020C5B8B84C0>
#
# swish
# <tensorflow.python.ops.custom_gradient.Bind object at 0x0000020C5B87EEB0>
#
# weighted_cross_entropy_with_logits
# <function weighted_cross_entropy_with_logits_v2 at 0x0000020C5B8B28B0>
#
# weighted_moments
# <function weighted_moments_v2 at 0x0000020C5B8B8790>
#
# zero_fraction
# <function zero_fraction at 0x0000020C5B8B81F0>
#
# atrous_conv2d
# <function atrous_conv2d at 0x0000020C5B2AEA60>
#
# atrous_conv2d_transpose
# <function atrous_conv2d_transpose at 0x0000020C5B2B11F0>
#
# avg_pool1d
# <function avg_pool1d at 0x0000020C5B2B65E0>
#
# avg_pool2d
# <function avg_pool2d at 0x0000020C5B2B6550>
#
# avg_pool3d
# <function avg_pool3d at 0x0000020C5B2B6670>
#
# avg_pool
# <function avg_pool_v2 at 0x0000020C5B2B6310>
#
# bias_add
# <function bias_add at 0x0000020C5B2B15E0>
#
# conv1d_transpose
# <function conv1d_transpose at 0x0000020C5B2AEDC0>
#
# conv1d
# <function conv1d_v2 at 0x0000020C5B2AEB80>
#
# conv2d_transpose
# <function conv2d_transpose_v2 at 0x0000020C5B2B1160>
#
# conv2d
# <function conv2d_v2 at 0x0000020C5B2AEE50>
#
# conv3d_transpose
# <function conv3d_transpose_v2 at 0x0000020C5B2B1430>
#
# conv3d
# <function conv3d_v2 at 0x0000020C5B2B1280>
#
# conv_transpose
# <function conv_transpose at 0x0000020C5B2B14C0>
#
# convolution
# <function convolution_v2 at 0x0000020C5B2AE670>
#
# crelu
# <function crelu_v2 at 0x0000020C5B2B1790>
#
# dilation2d
# <function dilation2d_v2 at 0x0000020C5B298EE0>
#
# dropout
# <function dropout_v2 at 0x0000020C5B2B6F70>
#
# erosion2d
# <function erosion2d_v2 at 0x0000020C5B2B8700>
#
# fractional_avg_pool
# <function fractional_avg_pool_v2 at 0x0000020C5B2B8430>
#
# fractional_max_pool
# <function fractional_max_pool_v2 at 0x0000020C5B2B8280>
#
# in_top_k
# <function in_top_k_v2 at 0x0000020C5B2B8820>
#
# leaky_relu
# <function leaky_relu at 0x0000020C5B2B18B0>
#
# log_softmax
# <function log_softmax_v2 at 0x0000020C5B2B1D30>
#
# max_pool1d
# <function max_pool1d at 0x0000020C5B2B6820>
#
# max_pool2d
# <function max_pool2d at 0x0000020C5B2B68B0>
#
# max_pool3d
# <function max_pool3d at 0x0000020C5B2B6940>
#
# max_pool
# <function max_pool_v2 at 0x0000020C5B2B6700>
#
# max_pool_with_argmax
# <function max_pool_with_argmax_v2 at 0x0000020C5B2B69D0>
#
# pool
# <function pool_v2 at 0x0000020C5B2AE9D0>
#
# relu6
# <function relu6 at 0x0000020C5B2B1820>
#
# softmax_cross_entropy_with_logits
# <function softmax_cross_entropy_with_logits_v2 at 0x0000020C5B2B1F70>
#
# softmax
# <function softmax_v2 at 0x0000020C5B2B1B80>
#
# sparse_softmax_cross_entropy_with_logits
# <function sparse_softmax_cross_entropy_with_logits_v2 at 0x0000020C5B2B63A0>
#
# top_k
# <function top_k at 0x0000020C5B2B8040>
#
# with_space_to_batch
# <function with_space_to_batch at 0x0000020C5B2AE1F0>
