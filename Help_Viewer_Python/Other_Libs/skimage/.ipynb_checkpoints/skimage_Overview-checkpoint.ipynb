# %%
import skimage
import skimage.feature

# %% [markdown]
# # skimage
#
# **DESCRIPTION**
#
# Image Processing SciKit (Toolbox for SciPy)
# ``scikit-image`` (a.k.a. ``skimage``) is a collection of algorithms for image
# processing and computer vision.
#
# The main package of ``skimage`` only provides a few utilities for converting
# between image data types; for most features, you need to import one of the
# following subpackages:
#
# **Subpackages**
#
# packeages|discription
# :--|:--
# color|Color space conversion.
# data|Test images and example data.
# draw|Drawing primitives (lines, text, etc.) that operate on NumPy arrays.
# exposure|Image intensity adjustment, e.g., histogram equalization, etc.
# feature|Feature detection and extraction, e.g., texture analysis corners, etc.
# filters|Sharpening, edge finding, rank filters, thresholding, etc.
# graph|Graph-theoretic operations, e.g., shortest paths.
# io|Reading, saving, and displaying images and video.
# measure|Measurement of image properties, e.g., similarity and contours.
# morphology|Morphological operations, e.g., opening or skeletonization.
# restoration|Restoration algorithms, e.g., deconvolution algorithms, denoising, etc.
# segmentation|Partitioning an image into multiple regions.
# transform|Geometric and other transforms, e.g., rotation or the Radon transform.
# util|Generic utilities.
# viewer|A simple graphical user interface for visualizing results and exploring parameters.
#
#
# **Utility Functions**
#
# - img_as_float
#
# - img_as_float32
#
# - img_as_float64
#
# - img_as_uint
#
# - img_as_int
#
# - img_as_ubyte
#
# - img_as_bool
#
# - dtype_limits
#
#
# **PACKAGE CONTENTS**
#
# - \_build
# - \_shared (package)
# - color (package)
# - conftest
# - data (package)
# - draw (package)
# - exposure (package)
# - external (package)
# - feature (package)
# - filters (package)
# - future (package)
# - graph (package)
# - io (package)
# - measure (package)
# - metrics (package)
# - morphology (package)
# - registration (package)
# - restoration (package)
# - scripts (package)
# - segmentation (package)
# - setup
# - transform (package)
# - util (package)
# - viewer (package)
#
# DATA
# - \_\_SKIMAGE_SETUP__ = False
# - data_dir = r'D:\ProgramFiles\miniconda3\lib\site-packages\skimage\data...
#
# **FILE**: d:\programfiles\miniconda3\lib\site-packages\skimage\\\_\_init__.py

# %% [markdown]
# help(skimage.feature)
#
# Help on package skimage.feature in skimage:
#
# NAME
#     skimage.feature
#
# PACKAGE CONTENTS
#     _canny
#     _cascade
#     _daisy
#     _haar
#     _hessian_det_appx
#     _hog
#     _hoghistogram
#     _texture
#     blob
#     brief
#     brief_cy
#     censure
#     censure_cy
#     corner
#     corner_cy
#     haar
#     masked_register_translation
#     match
#     orb
#     orb_cy
#     peak
#     register_translation
#     setup
#     template
#     tests (package)
#     texture
#     util
#
# CLASSES
#     builtins.object
#         skimage.feature._cascade.Cascade
#     skimage.feature.util.DescriptorExtractor(builtins.object)
#         skimage.feature.brief.BRIEF
#         skimage.feature.orb.ORB(skimage.feature.util.FeatureDetector, skimage.feature.util.DescriptorExtractor)
#     skimage.feature.util.FeatureDetector(builtins.object)
#         skimage.feature.censure.CENSURE
#         skimage.feature.orb.ORB(skimage.feature.util.FeatureDetector, skimage.feature.util.DescriptorExtractor)
#
# **FUNCTIONS**
# blob_dog(image, min_sigma=1, max_sigma=50, sigma_ratio=1.6, threshold=2.0, overlap=0.5, *, exclude_border=False)
#
#
# blob_doh(image, min_sigma=1, max_sigma=30, num_sigma=10, threshold=0.01, overlap=0.5, log_scale=False)
#
# blob_log(image, min_sigma=1, max_sigma=50, num_sigma=10, threshold=0.2, overlap=0.5, log_scale=False, *, exclude_border=False)
#
# canny(image, sigma=1.0, low_threshold=None, high_threshold=None, mask=None, use_quantiles=False)
#
# corner_fast(image, n=12, threshold=0.15)
#
# corner_foerstner(image, sigma=1)
#
# corner_harris(image, method='k', k=0.05, eps=1e-06, sigma=1)
#
# corner_kitchen_rosenfeld(image, mode='constant', cval=0)
#
# corner_moravec(image, window_size=1)
#
# corner_orientations(image, corners, mask)
#
# corner_peaks(image, min_distance=1, threshold_abs=None, threshold_rel=0.1, exclude_border=True, indices=True, num_peaks=inf, footprint=None, labels=None)
#
# corner_shi_tomasi(image, sigma=1)
#
# corner_subpix(image, corners, window_size=11, alpha=0.99)
#
# daisy(image, step=4, radius=15, rings=3, histograms=8, orientations=8, normalization='l1', sigmas=None, ring_radii=None, visualize=False)
#
# draw_haar_like_feature(image, r, c, width, height, feature_coord, color_positive_block=(1.0, 0.0, 0.0), color_negative_block=(0.0, 1.0, 0.0), alpha=0.5, max_n_features=None, random_state=None)
#
# draw_multiblock_lbp(image, r, c, width, height, lbp_code=0, color_greater_block=(1, 1, 1), color_less_block=(0, 0.69, 0.96), alpha=0.5)
#
# greycomatrix(image, distances, angles, levels=None, symmetric=False, normed=False)
#
# greycoprops(P, prop='contrast')
#
# haar_like_feature(int_image, r, c, width, height, feature_type=None, feature_coord=None)
#
# haar_like_feature_coord(width, height, feature_type=None)
#
# hessian_matrix(image, sigma=1, mode='constant', cval=0, order='rc')
#
# hessian_matrix_det(image, sigma=1, approximate=True)
#
# hessian_matrix_eigvals(H_elems)
#
# hog(image, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(3, 3), block_norm='L2-Hys', visualize=False, transform_sqrt=False, feature_vector=True, multichannel=None)
#
# local_binary_pattern(image, P, R, method='default')
#
# masked_register_translation(src_image, target_image, src_mask, target_mask=None, overlap_ratio=0.3)
#
# match_descriptors(descriptors1, descriptors2, metric=None, p=2, max_distance=inf, cross_check=True, max_ratio=1.0)
#
# match_template(image, template, pad_input=False, mode='constant', constant_values=0)
#
# multiblock_lbp(int_image, r, c, width, height)
#
# peak_local_max(image, min_distance=1, threshold_abs=None, threshold_rel=None, exclude_border=True, indices=True, num_peaks=inf, footprint=None, labels=None, num_peaks_per_label=inf)
#
# plot_matches(ax, image1, image2, keypoints1, keypoints2, matches, keypoints_color='k', matches_color=None, only_matches=False, alignment='horizontal')
#
# register_translation(src_image, target_image, upsample_factor=1, space='real', return_error=True)
#
#
# shape_index(image, sigma=1, mode='constant', cval=0)
#
#
# structure_tensor(image, sigma=1, mode='constant', cval=0)
#
# structure_tensor_eigvals(Axx, Axy, Ayy)
#
# DATA
#     __all__ = ['canny', 'Cascade', 'daisy', 'hog', 'greycomatrix', 'greyco...
#
# FILE
#     d:\programfiles\miniconda3\lib\site-packages\skimage\feature\__init__.py
