# %%
import sklearn.datasets as datasets

# %%
for k, v in datasets.__dict__.items():
    print(k, v, sep="\n")
# Out:
# __name__
# sklearn.datasets
# __doc__
#
# The :mod:`sklearn.datasets` module includes utilities to load datasets,
# including methods to load and fetch popular reference datasets. It also
# features some artificial data generators.
#
# __package__
# sklearn.datasets
# __loader__
# ...
# __spec__
# ModuleSpec(name='sklearn.datasets', loader=<_frozen_importlib_external.SourceFileLoader object at 0x00000221C4F224C8>, origin='D:\\ProgrammeFiles\\python\\Anaconda3\\envs\\tensorflow\\lib\\site-packages\\sklearn\\datasets\\__init__.py', submodule_search_locations=['D:\\ProgrammeFiles\\python\\Anaconda3\\envs\\tensorflow\\lib\\site-packages\\sklearn\\datasets'])
# __path__
# ['D:\\ProgrammeFiles\\python\\Anaconda3\\envs\\tensorflow\\lib\\site-packages\\sklearn\\datasets']
# __file__
# D:\ProgrammeFiles\python\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\datasets\__init__.py
# __cached__
# ...
